# %% [markdown]
# # Evaluate Proxima effect on trajectories
# Here we look at the experiments where we only train a model once in NPT and look for the oscillations and the effect of blending.

# %%
import os
from glob import glob
from datetime import datetime

# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib as mpl
import matplotlib.patches as mpatches

from cascade.learning.torchani import TorchANI
from pathlib import Path
from ase.io import read
from ase import units
import pickle as pkl
import pandas as pd
import numpy as np
import json

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# /home/mike/miniconda3/envs/cascade/lib/python3.11/site-packages/torchani/aev.py:16: UserWarning: cuaev not installed
#   warnings.warn("cuaev not installed")
# /home/mike/miniconda3/envs/cascade/lib/python3.11/site-packages/ignite/handlers/checkpoint.py:16: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import ZeroRedundancyOptimizer

# %% [markdown]
# ## Read in data

# %%
run_dirs = sorted(glob('runs/800K-npt-single-train/*'))
run_dirs
# Out:
# ['runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-00e6f7df',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-05bd7fef',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-0aff6fba',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-105292bb',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-1418cfda',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-160f5dc6',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-1ffe8b75',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-24aacf2b',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-2fc33503',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-399f3417',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-3c135b25',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-41bda030',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-4202e855',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-43ad29a4',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-4e1470ea',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-5271547c',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-576ac2ca',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-68015472',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-6a2330a6',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-704a7aac',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-741e74e4',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-7c306fa4',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-85ae0c38',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-86fcda47',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-8c47d5f6',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-8d284b8b',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-8ea1b743',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-a5de4688',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-a74eb1ba',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-a87fe7ca',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-aea7d1fc',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-b0bcd4c2',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-bec1053a',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-d842a077',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-df641e0d',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-e4161130',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-e8ec045c',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-ec64d6a6',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-f3b5ef7a',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-f7c408bc',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-fdf74584',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=0-ffae3d1c',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-0474190d',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-06819c7d',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-0a8231d9',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-0ae9d559',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-15ddd631',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-194cd314',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-1c126fcf',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-1eb38402',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-2c3cc071',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-394f272e',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-4121c393',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-42e4fc56',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-5103b1b4',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-5218bab6',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-58c32d14',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-842df0f8',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-886af225',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-920fcbea',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-978dd067',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-97cff3ba',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-9a21eaf5',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-9b031a63',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-9bd27cec',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-ada08444',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-b205a31d',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-b51ee3f9',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-bae87197',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-c0686dc3',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-cfe15dbd',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-d173d31b',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-e42250b5',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-ea0e361c',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-f5572179',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-f5e2641c',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-fbcb0b24',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=10-ffe10d1f',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-02638a3a',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-19e496e9',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-1b02f9bf',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-1c8823dd',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-1eec1d0c',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-27b761b4',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-2d3b2466',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-3ab0d937',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-3e2e99f7',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-410c7293',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-43293701',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-480f3f83',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-505dc0ee',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-54c03254',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-581af226',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-5a69aa7e',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-6b53c4f0',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-6bd8440d',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-729b9c6a',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-74ab06f2',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-7e942cad',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-8ae14c5e',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-8d3aa32a',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-9066ba4f',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-9fb6a2d7',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-b4f49416',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-d90b4754',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-dd2c9b98',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-dd7be245',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-de3a275a',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-e0a9558a',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-ed7be914',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-ef76acbf',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-f05b5eda',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-fd4e303c',
#  'runs/800K-npt-single-train/si-vacancy-2x2x2-temp=800.0-method=lda-blend=20-ff55457c']

# %%
len(run_dirs)
# Out:
# 114

# %%
param_vars = ['seed', 'temperature', 'n_blending_steps', 'min_target_frac', 'target_error', 'stress_tau', 'steps']

# %% [markdown]
# ## Look at the run parameters

# %%
params = []
for d in run_dirs:
    try:
        params.append(json.loads((Path(d)/'params.json').read_text()))
    except: 
        print(f'couldnt find {d}/params.json; skipping')
        continue
    params[-1]['dir'] = d
params = pd.DataFrame(params)

# %% [markdown]
# ## read in the runs and append the hash

# %%
data = []
hashes = []
for i, row in params.iterrows(): 
    # read in the results for each set of parameters
    run = row['dir']
    try:
        _data = pd.read_json(Path(run)/'proxima-log.json', lines=True)
    except: 
        print('couldnt read proximal log for', run)
        hashes.append(None)
        continue
    # make sure to have timestep
    _data.reset_index(names='timestep', inplace=True)

    # keep the hash of the run
    _hash = run.split('-')[-1]
    hashes.append(_hash)
    _data['hash'] = _hash 
    #traj = read(Path(run)/'md.traj', index=':')
    #break    
    # add the parameters to the experiment df for easy plotting, grouping, etc
    for var in param_vars:
        _data[var] = row[var]
    data.append(_data)

# track the hashes as well for param lookup
params['hash'] = hashes
data = pd.concat(data)

# %%
_params = params[param_vars+['hash']].sort_values(param_vars)
_params.describe()
# Out:
#              seed  temperature  n_blending_steps  min_target_frac  target_error  stress_tau   steps
# count  114.000000        114.0        114.000000       114.000000  1.140000e+02       114.0   114.0
# mean     2.500000        800.0          9.473684         0.305263  6.394737e-01        25.0  2048.0
# std      1.715365          0.0          8.291386         0.233800  2.670284e-01         0.0     0.0
# min      0.000000        800.0          0.000000         0.100000  1.000000e-12        25.0  2048.0
# 25%      1.000000        800.0          0.000000         0.100000  4.500000e-01        25.0  2048.0
# 50%      2.500000        800.0         10.000000         0.200000  4.500000e-01        25.0  2048.0
# 75%      4.000000        800.0         20.000000         0.500000  9.000000e-01        25.0  2048.0
# max      5.000000        800.0         20.000000         1.000000  9.000000e-01        25.0  2048.0

# %%
_params.duplicated().sum()
# Out:
# 0

# %%
data['hash'].value_counts().unique()
# Out:
# array([2048])

# %%
runs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 runs
#
# NameError: name 'runs' is not defined

# %%
runs['hash'][(runs['min_target_frac'] != 1) & runs['n_blending_steps'] == 0]
# Out:
# 1    46eaa9f3
# 5    daefb0ba
# 8    72b94ed1
# Name: hash, dtype: object

# %%
for seed in range(4):

    fig, ax = plt.subplots(figsize=(12,5))
    runs = _params.query(f'seed == {seed}')
    dft_hash = runs['hash'][runs['min_target_frac'] == 1].item()
    blend_hash = runs['hash'][runs['n_blending_steps'] == 10].item()
    proxima_hash = runs['hash'][(runs['min_target_frac'] != 1) & (runs['n_blending_steps'] == 0)].item()

    blend_traj = data.query(f'hash == "{blend_hash}"')
    proxima_traj = data.query(f'hash == "{proxima_hash}"')
    dft_traj = data.query(f'hash == "{dft_hash}"')
    
    plt.plot(proxima_traj['volume'], label='proxima')
    plt.plot(blend_traj['volume'], label='blend')
    plt.plot(dft_traj['volume'], label='dft', color='k', linestyle='dashed')
    plt.title(f"seed={seed}")
    plt.xlim(2048*1.5, 2048*1.75)#, 4096)
    plt.legend()
    plt.show()

# %%
blend_hash, proxima_hash
# Out:
# ('ecddd413', 'cae8e042')

# %%
data.columns
# Out:
# Index(['timestep', 'step_time', 'energy', 'maximum_force', 'stress', 'temperature', 'volume', 'used_surrogate', 'proxima_alpha', 'proxima_threshold', 'proxima_blending_step', 'proxima_lambda_target', 'last_uncer', 'last_error', 'total_invocations', 'target_invocations', 'model_version', 'hash', 'seed', 'n_blending_steps', 'min_target_frac', 'target_error', 'stress_tau', 'steps'], dtype='object')

# %%
data.head()
# Out:
#    timestep  step_time       energy  maximum_force                                             stress  temperature       volume  used_surrogate  proxima_alpha  proxima_threshold  proxima_blending_step  proxima_lambda_target  last_uncer  last_error  total_invocations  target_invocations  model_version      hash  seed  n_blending_steps  min_target_frac  target_error  stress_tau  steps
# 0         0   8.758060 -6684.002357       0.640134  [-0.034064950674633006, -0.033984689113805006,...        800.0  1280.824056           False            NaN                NaN                      0                    NaN    0.009403    0.640530                  2                   2              0  01805009     3                 0              0.1           4.5        25.0   4096
# 1         1   5.152223 -6683.932374       0.912785  [-0.033752275089244, -0.033582710657265, -0.03...        800.0  1281.572936           False            NaN                NaN                      0                    NaN    0.009850    0.913031                  3                   3              0  01805009     3                 0              0.1           4.5        25.0   4096
# 2         2   5.363058 -6683.804736       1.176208  [-0.033485458901801005, -0.033220645502494005,...        800.0  1282.324309           False            NaN                NaN                      0                    NaN    0.010252    1.176584                  4                   4              0  01805009     3                 0              0.1           4.5        25.0   4096
# 3         3   5.209425 -6683.649263       1.423889  [-0.03286263072042, -0.032495885968113, -0.033...        800.0  1283.811212           False            NaN                NaN                      0                    NaN    0.010610    1.424672                  5                   5              0  01805009     3                 0              0.1           4.5        25.0   4096
# 4         4   6.549386 -6683.448237       1.654450  [-0.032272771383617005, -0.031801034537219997,...        800.0  1285.304909           False            NaN                NaN                      0                    NaN    0.010902    1.655874                  6                   6              0  01805009     3                 0              0.1           4.5        25.0   4096

# %%
data.describe()
# Out:
#            timestep     step_time         energy  maximum_force  temperature        volume  proxima_alpha  proxima_threshold  proxima_blending_step  proxima_lambda_target    last_uncer    last_error  total_invocations  target_invocations  model_version          seed  n_blending_steps  min_target_frac  target_error  stress_tau    steps
# count  11401.000000  11401.000000   11401.000000   11401.000000      11401.0  1.140100e+04   1.132900e+04       11329.000000           11401.000000            2052.000000  11401.000000  11401.000000       11401.000000        11401.000000        11401.0  11401.000000      11401.000000     1.140100e+04       11401.0     11401.0  11401.0
# mean     806.262258      9.213554   -2200.911061       3.258944        800.0  1.641149e+61   6.394790e+04           0.207257               1.447154               0.190505      0.043212     11.214237        1295.006578          378.981230            0.0      1.662661          1.799842     1.000000e-01           4.5        25.0   4096.0
# std      852.740925     23.472287    4872.564173      11.090490          0.0  1.749865e+63   1.706327e+06           0.237708               3.470836               0.378642      0.021601     22.126832        1206.073512          545.777944            0.0      1.040858          3.841912     5.135007e-15           0.0         0.0      0.0
# min        0.000000      0.026517   -7121.328324       0.000000        800.0  2.955760e+02   3.451950e+01           0.000000               0.000000               0.000000      0.000000      0.572873           2.000000            2.000000            0.0      0.000000          0.000000     1.000000e-01           4.5        25.0   4096.0
# 25%      237.000000      0.122674   -6589.670443       0.033181        800.0  1.504025e+03   8.753427e+01           0.017953               0.000000               0.000000      0.031040      2.949461         425.000000           84.000000            0.0      1.000000          0.000000     1.000000e-01           4.5        25.0   4096.0
# 50%      494.000000      0.360845      -4.351285       0.050948        800.0  1.764631e+03   1.286227e+02           0.129596               0.000000               0.000000      0.041564      4.725021         877.000000          171.000000            0.0      2.000000          0.000000     1.000000e-01           4.5        25.0   4096.0
# 75%      982.000000      9.769727       0.315702       3.386726        800.0  2.381811e+03   2.210645e+02           0.292187               0.000000               0.024472      0.053374     10.167197        1720.000000          332.000000            0.0      2.000000          0.000000     1.000000e-01           4.5        25.0   4096.0
# max     3454.000000    597.178272  396062.784506     396.906314        800.0  1.868425e+65   7.542477e+07           1.206087              10.000000               1.000000      0.263807    396.874250        4691.000000         2329.000000            0.0      3.000000         10.000000     1.000000e-01           4.5        25.0   4096.0

# %%
data.hash.nunique()
# Out:
# 12

# %% [markdown]
# ## Plot DFT only trajectories

# %%
dft_only = data.query('min_target_frac == 1')

# %% [markdown]
# First I verify that the DFT only trajectories are what I think they are:

# %%
only_target = (dft_only['total_invocations']==dft_only['target_invocations']).all()
assert only_target, 'target was not always invoked'
only_target
# Out:
# True

# %%
dft_only.hash.nunique()
# Out:
# 0

# %%
no_blend = (dft_only['proxima_blending_step'] == 0).all()
assert no_blend, 'proxima should not blend'
no_blend
# Out:
# True

# %%
for i, (g, row) in enumerate(dft_only.sort_values(['hash'] + param_vars).groupby(param_vars)): 
    fig, ax = plt.subplots(figsize=(15,2.5))
    plt.plot(row['timestep'], row['volume'], '-o', ms=1)
    plt.ylabel('V ($\AA ^3$)')
    plt.xlabel('time (fs)')

    _params = params.query(f'hash == "{row["hash"].iloc[0]}"')
    _params = ', '.join([f'{var}={_params[var].iloc[0]}' for var in param_vars])
    plt.title(f"DFT-only " + _params)
    plt.tight_layout()
    plt.show()

# %%
dft_only
# Out:
# Empty DataFrame
# Columns: [timestep, step_time, energy, maximum_force, stress, temperature, volume, used_surrogate, proxima_alpha, proxima_threshold, proxima_blending_step, proxima_lambda_target, last_uncer, last_error, total_invocations, target_invocations, model_version, hash, seed, n_blending_steps, min_target_frac, target_error, stress_tau, steps]
# Index: []

# %% [markdown]
# ## Plot proxima + blending trajectories
#
# this plots all of them, which is good for a quick inspection

# %%
experimental = data.query('min_target_frac < 1')

# %% [raw]
# %%time
# for n_blend in sorted(params['n_blending_steps'].unique()):
#     _data = data.query(f'min_target_frac < 1 and n_blending_steps == {n_blend}')
#     print('*'*100)
#     print(f'{n_blend=}')
#     for i, (g, row) in enumerate(_data.sort_values(['hash'] + param_vars).groupby(param_vars)):
#         fig, ax = plt.subplots(2, figsize=(60,2.5*2))
#         plt.sca(ax[0])
#         plt.plot(row['timestep'], row['volume'], '-o', ms=1)
#         plt.ylabel('V ($\AA^3$)')
#         plt.xlabel('time (fs)')
#
#         _params = params.query(f'hash == "{row["hash"].iloc[0]}"')
#         _params = ', '.join([f'{var}={_params[var].iloc[0]}' for var in param_vars])
#         plt.title(_params)
#
#         plt.sca(ax[1])
#
#         if n_blend == 0:
#             plt.plot(row['timestep'], row['used_surrogate'])
#             plt.ylabel('Used surrogate')
#         else:
#             plt.plot(row['timestep'], 1-row['proxima_lambda_target'])
#             plt.ylabel('$\lambda_{ML}$')
#         plt.xlabel('time (fs)')
#         plt.tight_layout()
#         plt.show()
#         print('hash=', row['hash'].unique())

# %% [markdown]
# ## Make a detailed plot of a single trajectory
# This is a good paper/slide figure

# %%
ref_traj = dft_only.query('temperature == 800 and steps == 2048 and seed == 0')
blend_traj = data.query('hash == "ecddd413"')

# %%
rc = {'axes.titlesize':12, 
      'axes.labelsize':14, 
      'xtick.labelsize': 12, 
      'ytick.labelsize': 12, 
      'legend.fontsize': 12}

# %%
with mpl.rc_context(rc=rc):
    xlim = (1000, 1600)
    fig, ax = plt.subplots(1, figsize=(10,2.5))
    ax.plot(ref_traj['volume'], color='k', linestyle='dashed', label='DFT (reference)')
    ax.legend(#title='Forces', 
              #loc='upper center', 
              #bbox_to_anchor=(0.5, 1.25),
              framealpha=1
             )
    ax.set_ylabel('Volume ($\mathrm{\AA}^3$)')
    ax.set_xlabel('time (fs)')
    plt.savefig('dft-only.png', dpi=500, bbox_inches='tight')
    plt.show()

# %%
with mpl.rc_context(rc=rc):
    #xlim = (1000, 1600)
    fig, axs = plt.subplots(1, figsize=(10,2.5))
    ax = axs
    
    l2 = ax.plot(ref_traj['volume'], color='k', linestyle='dashed', label='DFT (reference)')
    l1 = ax.plot(traj['volume'], color='tab:blue', label='Proxima')
    ax.set_ylabel('Volume ($\mathrm{\AA}^3$)')
    ax.set_xlabel('time (fs)')
    c = ax.pcolorfast(ax.get_xlim(), 
                  ax.get_ylim(), 
                  traj['used_surrogate'].values[np.newaxis], 
                  alpha=0.3, 
                  cmap='Blues', 
                  label='Used ML')
    ax.set_xlim(*xlim)
    
    blue_patch = mpatches.Patch(color='#afbbcb', label='Used surrogate')
    leg, lab = ax.get_legend_handles_labels()
    leg.append(blue_patch)
    lab.append('Used Surrogate')
    plt.legend(leg, 
               lab, 
               loc='upper left',
               framealpha=0.8, 
               bbox_to_anchor=(0.0, 1.25),
              )
    plt.axvline(1023, color='k')
    plt.tight_layout()
    plt.savefig('dft-proxima.png', dpi=500)
    plt.show()

# %%
with mpl.rc_context(rc=rc):
    xlim = (1000, 1600)
    fig, axs = plt.subplots(2, figsize=(10,5))
    ax = axs[0]
    
    #l2 = ax.plot(ref_traj['volume'], color='k', linestyle='dashed', label='DFT (reference)')
    l1 = ax.plot(traj['volume'], color='tab:blue', label='Proxima')
    l2 = ax.plot(blend_traj['volume'], color='tab:red', label='Proxima+Blend')
    ax.set_ylabel('Volume ($\mathrm{\AA}^3$)')
    ax.set_xlabel('time (fs)')
    ax.pcolorfast(ax.get_xlim(), 
                  ax.get_ylim(), 
                  traj['used_surrogate'].values[np.newaxis], 
                  alpha=0.3, 
                  cmap='Blues', label='Used ML') 
    
    # can give it fill between just to get the legend
    
    ax.axvline(1023, color='k')
    ax.set_xlim(*xlim)
    #ax.fill_between(traj['volume'], traj['used_surrogate'], 1, where=(traj['used_surrogate' ]>0), color='red', alpha=0.2)
    blue_patch = mpatches.Patch(color='#afbbcb', label='Used surrogate (Proxima only)')
    leg, lab = ax.get_legend_handles_labels()
    leg.append(blue_patch)
    lab.append('Proxima used surrogate')
    ax.legend(leg, 
               lab, 
               loc='upper left',
               framealpha=0.8, 
               bbox_to_anchor=(0.0, 1.35),
              )
    ax = axs[1]
    lambda_ml = 1-blend_traj['proxima_lambda_target']
    ax.plot(lambda_ml, color='tab:red')
    ax.axvline(1023, color='k')
    ax.set_xlim(*xlim)
    ax.set_ylabel('$\lambda_\mathrm{ML}$')
    ax.set_xlabel('time (fs)')
    plt.tight_layout()
    plt.savefig('dft-proxima-blend.png', dpi=500)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 7
#       4 ax = axs[0]
#       6 #l2 = ax.plot(ref_traj['volume'], color='k', linestyle='dashed', label='DFT (reference)')
# ----> 7 l1 = ax.plot(traj['volume'], color='tab:blue', label='Proxima')
#       8 l2 = ax.plot(blend_traj['volume'], color='tab:red', label='Proxima+Blend')
#       9 ax.set_ylabel('Volume ($\mathrm{\AA}^3$)')
#
# NameError: name 'traj' is not defined

# %%
traj['step_time'].argmax()
# Out:
# 1023

# %%
blend_traj['step_time'].argmax()
# Out:
# 1023

# %%
traj.iloc[1024:]['used_surrogate'].mean()
# Out:
# 0.4453125

# %%
blend_traj[1024:]['used_surrogate'].mean()
# Out:
# 0.830078125

# %%
blend_traj['full_surrogate'] = blend_traj['used_surrogate'] & (blend_traj['proxima_lambda_target'] == 0)
# Out:
# /tmp/ipykernel_485763/2618731154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blend_traj['full_surrogate'] = blend_traj['used_surrogate'] & (blend_traj['proxima_lambda_target'] == 0)

# %%
blend_traj.iloc[1024:]['full_surrogate'].mean()
# Out:
# 0.7841796875

# %% [markdown]
# ## Summary quantities
# Here we'll average some quantities over our experimental conditions to get a sense of whats happening in aggregate

# %% [markdown]
# ### Combining the dft data in for seaborn
# This is a little sneaky, but it will get the DFT data on the seaborn plots without me having to plot things manualy

# %%
dft_only['target_error'] = 0.45
# Out:
# /tmp/ipykernel_485763/3036850189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft_only['target_error'] = 0.45

# %%
_dft_only = dft_only.copy()
_dft_only['target_error'] = 0.9
dft_only = pd.concat([dft_only, _dft_only])

# %%
experimental = pd.concat([experimental, dft_only])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 experimental = pd.concat([experimental, dft_only])
#
# NameError: name 'experimental' is not defined

# %% [markdown]
# ## Volume

# %% [markdown]
# Takeaways:
# * the volume matches DFT for the smaller target error (0.45)
# * For the larger target error, blending only really matters for larger target fractions
#    - 0.5 target fraction matches dft well, probably because mostly using DFT
#
# * Notably even the largest errors are quite small percentage wise

# %%
v_mean = experimental.query('timestep > 1024').groupby(param_vars)['volume'].mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 v_mean = experimental.query('timestep > 1024').groupby(param_vars)['volume'].mean().reset_index()
#
# NameError: name 'experimental' is not defined

# %%
v_mean.head()
g = sns.catplot(x='n_blending_steps',
            col='min_target_frac', 
            row='target_error',
            y='volume',
            data=v_mean.query('volume < 1e5'),
            sharey=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 v_mean.head()
#       2 g = sns.catplot(x='n_blending_steps',
#       3             col='min_target_frac',
#       4             row='target_error',
#       5             y='volume',
#       6             data=v_mean.query('volume < 1e5'),
#       7             sharey=True)
#       8 plt.show()
#
# NameError: name 'v_mean' is not defined

# %% [markdown]
# ## Target fraction
#
# Contextualizing the above results, the takeaways:
# * for 0.45 target error, we are accurate because we just use the DFT almost all of the time
# * Same goes for the large min target frac + blending case

# %%
frac_target = []
for _hash, g  in experimental.groupby('hash'): 
    frac_target.append((_hash, g['target_invocations'].iloc[-1] / g['total_invocations'].iloc[-1]))
frac_target = pd.DataFrame.from_records(frac_target, columns=['hash', 'frac_target'])

# %%
frac_target = pd.merge(frac_target, params.query('min_target_frac < 1'), on='hash', how='left')

# %%
g = sns.catplot(x='n_blending_steps',
            col='min_target_frac', 
            row='target_error',
            y='frac_target',
            data=frac_target,
            sharey=True,
            sharex=False)
plt.show()

# %% [markdown]
# ## What's going on with the min target fraction? Can we look at whether we're being too cautious vs too optimistic?
#
# And does that relate to what we see in this plot? Perhaps measuring this class of mistake is a direction of future work? e.g. control on an FPR/FNR?

# %% [markdown]
# ## Gradients
#
# I look at the gradient in volume (per fs, so no demonimator).
# This should relate to the rapid oscillations. So hopefully blending makes it go away.
#
# You can adjust the y variable in the catplot to see the effect in both the mean and max first and second order derivative
#
#
# The takeaway from the max first derivative is that
# * for smaller target error -- it doesnt matter (unsurprising since in that cas we just use the DFT)
# * for larger target error there are some huge gradients for no blending, but on about the right scale with blending

# %%
params
# Out:
#      file                                      starting_strc  temperature  timestep calculator ensemble  temp_tau  stress_tau  steps  seed  bulk_modulus model_type initial_model initial_data  ensemble_size  online_training  training_epochs  training_batch_size training_max_size  training_recency_bias training_device  target_error  error_history  retrain_freq  min_target_frac  n_blending_steps                            cascade_commit                                 my_commit                  start_time                                                dir      hash
# 0    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.971892  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  00e6f7df
# 1    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.990908  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  05bd7fef
# 2    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T16:40:41.998016  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  0aff6fba
# 3    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T16:29:39.827520  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  105292bb
# 4    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  1.000000e-12              8          1024              1.0                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T16:04:19.628837  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  1418cfda
# 5    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.995349  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  160f5dc6
# 6    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.142338  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  1ffe8b75
# 7    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.153744  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  24aacf2b
# 8    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.981273  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  2fc33503
# 9    None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.186546  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  399f3417
# 10   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  1.000000e-12              8          1024              1.0                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T03:40:17.182227  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  3c135b25
# 11   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:15:23.112136  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  41bda030
# 12   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:11:22.357315  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  4202e855
# 13   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:48:00.005982  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  43ad29a4
# 14   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  1.000000e-12              8          1024              1.0                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T16:37:37.719562  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  4e1470ea
# 15   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:48:00.000332  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  5271547c
# 16   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.998666  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  576ac2ca
# 17   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:11:50.341854  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  68015472
# 18   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  1.000000e-12              8          1024              1.0                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T03:29:28.890090  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  6a2330a6
# 19   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.174012  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  704a7aac
# 20   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T16:32:43.730065  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  741e74e4
# 21   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  1.000000e-12              8          1024              1.0                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T03:46:35.345846  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  7c306fa4
# 22   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.181690  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  85ae0c38
# 23   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.171230  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  86fcda47
# 24   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.982537  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  8c47d5f6
# 25   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.988304  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  8d284b8b
# 26   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.184785  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  8ea1b743
# 27   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.157362  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  a5de4688
# 28   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.168891  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  a74eb1ba
# 29   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.169507  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  a87fe7ca
# 30   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:19:39.329217  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  aea7d1fc
# 31   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.992272  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  b0bcd4c2
# 32   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T16:27:42.514397  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  bec1053a
# 33   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.191000  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  d842a077
# 34   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  1.000000e-12              8          1024              1.0                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T04:01:24.511453  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  df641e0d
# 35   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:48:00.003974  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  e4161130
# 36   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:21:09.333658  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  e8ec045c
# 37   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.189463  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  ec64d6a6
# 38   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.175778  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  f3b5ef7a
# 39   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.975125  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  f7c408bc
# 40   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.150579  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  fdf74584
# 41   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                 0  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T13:57:01.141084  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  ffae3d1c
# 42   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:48:52.016421  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  0474190d
# 43   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T20:52:42.539486  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  06819c7d
# 44   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T20:47:58.894348  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  0a8231d9
# 45   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T19:12:31.181920  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  0ae9d559
# 46   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T13:24:10.954256  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  15ddd631
# 47   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T19:03:57.708926  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  194cd314
# 48   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:32:33.599467  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  1c126fcf
# 49   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T22:24:16.628587  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  1eb38402
# 50   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T21:01:22.830385  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  2c3cc071
# 51   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:25:40.371338  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  394f272e
# 52   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T13:04:41.906361  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  4121c393
# 53   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T18:38:44.409169  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  42e4fc56
# 54   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T20:47:36.729155  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  5103b1b4
# 55   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T19:28:40.478282  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  5218bab6
# 56   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.986209  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  58c32d14
# 57   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T20:54:13.296741  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  842df0f8
# 58   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:36:19.832706  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  886af225
# 59   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T13:29:26.929701  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  920fcbea
# 60   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T19:38:09.016652  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  978dd067
# 61   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T19:25:54.456124  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  97cff3ba
# 62   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:28:11.008974  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  9a21eaf5
# 63   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T22:04:12.794981  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  9b031a63
# 64   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T20:50:27.183497  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  9bd27cec
# 65   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T13:14:01.161049  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  ada08444
# 66   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T19:48:17.845584  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  b205a31d
# 67   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:27:53.871934  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  b51ee3f9
# 68   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T17:26:05.689848  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  bae87197
# 69   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:48:00.002642  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  c0686dc3
# 70   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:47:59.974111  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  cfe15dbd
# 71   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T13:29:26.931074  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  d173d31b
# 72   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T18:43:52.406848  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  e42250b5
# 73   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T10:48:52.017891  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  ea0e361c
# 74   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T19:36:40.753201  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  f5572179
# 75   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T13:04:28.556537  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  f5e2641c
# 76   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T22:11:32.889216  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  fbcb0b24
# 77   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                10  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T13:20:50.650612  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  ffe10d1f
# 78   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T01:37:11.645991  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  02638a3a
# 79   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T00:14:28.354749  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  19e496e9
# 80   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T13:30:49.353614  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  1b02f9bf
# 81   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T23:49:43.068210  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  1c8823dd
# 82   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T00:43:38.437173  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  1eec1d0c
# ...
# 86   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T15:42:01.922383  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  3e2e99f7
# 87   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T23:08:26.176783  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  410c7293
# 88   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T14:04:00.099177  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  43293701
# 89   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T01:53:25.249371  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  480f3f83
# 90   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T15:36:14.917068  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  505dc0ee
# 91   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T03:09:43.445053  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  54c03254
# 92   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T14:16:20.917012  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  581af226
# 93   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T02:37:44.588299  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  5a69aa7e
# 94   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T23:04:34.104865  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  6b53c4f0
# 95   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T14:06:43.348618  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  6bd8440d
# 96   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T02:21:02.224705  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  729b9c6a
# 97   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T14:23:06.924350  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  74ab06f2
# 98   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T22:52:50.920374  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  7e942cad
# 99   None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T00:07:06.827029  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  8ae14c5e
# 100  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T22:53:38.933724  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  8d3aa32a
# 101  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T02:37:44.591032  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  9066ba4f
# 102  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T00:20:28.184051  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  9fb6a2d7
# 103  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T23:26:10.681273  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  b4f49416
# 104  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T02:48:38.205116  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  d90b4754
# 105  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     2          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T22:32:23.117864  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  dd2c9b98
# 106  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T00:51:28.518016  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  dd7be245
# 107  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     3          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T02:12:08.983234  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  de3a275a
# 108  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T02:25:31.934165  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  e0a9558a
# 109  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     4          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-22T01:06:50.343293  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  ed7be914
# 110  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.1                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T14:05:54.133017  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  ef76acbf
# 111  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     5          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.5                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-21T23:01:15.693769  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  f05b5eda
# 112  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     1          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  4.500000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T14:12:41.314400  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  fd4e303c
# 113  None  /home/mtynes/cascade/0_setup/initial-geometrie...        800.0         1        lda      npt        25        25.0   2048     0          98.0        ani          None           []              2             True               32                   32              None                    1.0             cpu  9.000000e-01              8          1024              0.2                20  884fa037daca2f12f3c528117ba8a386033dfd71  884fa037daca2f12f3c528117ba8a386033dfd71  2024-08-20T15:47:50.870334  runs/800K-npt-single-train/si-vacancy-2x2x2-te...  ff55457c

# %%
v_diff = []
for _hash, g  in data.groupby('hash'): 
    diff = g['volume'].diff().abs()
    v_diff.append((_hash, diff.max(), diff.mean(), diff.std()))
v_diff = pd.DataFrame.from_records(v_diff, columns=['hash', 'diff_max', 'diff_mean', 'diff_sd'])

# %%
params = pd.merge(params, v_diff, on='hash')

# %%
v_diff = []
for _hash, g  in data.groupby('hash'): 
    diff = g['volume'].diff(2).abs()
    v_diff.append((_hash, diff.max(), diff.mean(), diff.std()))
v_diff = pd.DataFrame.from_records(v_diff, columns=['hash', 'diff2_max', 'diff2_mean', 'diff2_sd'])

# %%
params = pd.merge(params, v_diff, on='hash')

# %%
g = sns.catplot(x='n_blending_steps',
            col='min_target_frac', 
            row='target_error',
            y='diff_max',
            #kind='box',
            #hue='seed',
            data=params,
            sharey=False,
            sharex=False)
plt.show()
#g.set(yscale='log')

# %% [markdown]
# ### Zoomed in plot
# We'll just look at the target_error=0.9 and min_target_frac=0.1 case
# This is a good paper/slide figure

# %%
_data = params.query('target_error == 0.9 or target_error == 1e-12')
_data.loc[:, 'n_blend'] = pd.Categorical(_data['n_blending_steps'].astype('str'))
_data.loc[:, 'n_blend'] = _data['n_blend'].cat.add_categories(['DFT (reference)'])
_data.loc[_data['min_target_frac'] == 1, 'n_blend'] = 'DFT (reference)'
_data['n_blend'].cat.categories
# Out:
# /tmp/ipykernel_640377/657806853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _data.loc[:, 'n_blend'] = pd.Categorical(_data['n_blending_steps'].astype('str'))
# /tmp/ipykernel_640377/657806853.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0', '0', '0', '0', '0', ..., '20', '20', '20', '20', '20']
# Length: 60
# Categories (4, object): ['0', '10', '20', 'DFT (reference)']' has dtype incompatible with category, please explicitly cast to a compatible dtype first.
#   _data.loc[:, 'n_blend'] = _data['n_blend'].cat.add_categories(['DFT (reference)'])
# Index(['0', '10', '20', 'DFT (reference)'], dtype='object')

# %%
_data['n_blend'].unique()
# Out:
# ['0', 'DFT (reference)', '10', '20']
# Categories (4, object): ['0', '10', '20', 'DFT (reference)']

# %%
meth = []
for i, row in _data.iterrows():
    if row['n_blend'] == '0':
        meth.append('Proxima')
    elif row['n_blend'] == 'DFT (reference)': 
        meth.append('DFT (reference)')
    else: 
        meth.append('Proxima + blend')
_data['Method'] = pd.Categorical(meth, categories=['Proxima', 'Proxima + blend', 'DFT (reference)'])
# Out:
# /tmp/ipykernel_640377/3253428738.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _data['Method'] = pd.Categorical(meth, categories=['Proxima', 'Proxima + blend', 'DFT (reference)'])

# %%
_data = _data.query('min_target_frac == 0.1 or min_target_frac == 1')
#_data = _data[_data['n_blend'] != "20"]
#_data['n_blend'] = _data['n_blend'].cat.remove_unused_categories()
ax = sns.swarmplot(x='n_blend', 
            y='diff_max',
            data=_data,
            hue='Method',
           )
plt.yscale('log')
plt.ylabel('$\max_t$ $[dV/dt]$ ($\AA^3/fs$)')
plt.show()
plt.savefig('volume_gradient_by_method.png', dpi=500)

# %% [markdown]
# Since the difference between 10 and 20 is quite small, lets just do blending vs no blending.
# And to make it more clear

# %%
_data['hash'].nunique()
# Out:
# 1

# %%
fig, ax = plt.subplots(figsize=(3,3))

_data = _data[_data['n_blend'] != "20"]
_data['n_blend'] = _data['n_blend'].cat.remove_unused_categories()
sns.boxplot(x='n_blend', 
            y='diff_max',
            data=_data,
            hue='Method',
            boxprops=dict(alpha=.6),
            showfliers=False,
            ax=ax
           )
ax.get_legend().remove()
sns.swarmplot(x='n_blend', 
            y='diff_max',
            data=_data,
            hue='Method',
            ax=ax,
            size=7
            )
leg, hand = ax.get_legend_handles_labels()
leg, hand = map(lambda l: l[3:], [leg, hand])
ax.legend(leg, hand, title='Method')
plt.ylabel('$\max_t$ $[dV/dt]$ ($\AA^3/fs$)')
plt.savefig('volume_gradient_by_method.png', dpi=500, bbox_inches='tight')
plt.show()
# Out:
# /home/mike/miniconda3/envs/cascade/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
OLS = ols(formula = 'diff_max ~ C(n_blend)', data = _data).fit()
OLS.summary()
# Out:
# /home/mike/miniconda3/envs/cascade/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   res = hypotest_fun_out(*samples, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               diff_max   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     8.596
# Date:                Wed, 11 Dec 2024   Prob (F-statistic):            0.00326
# Time:                        14:21:09   Log-Likelihood:                -64.864
# No. Observations:                  18   AIC:                             135.7
# Df Residuals:                      15   BIC:                             138.4
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        26.0431      3.975      6.552      0.000      17.572      34.515
# C(n_blend)[T.10]                -20.1506      5.621     -3.585      0.003     -32.131      -8.170
# C(n_blend)[T.DFT (reference)]   -20.2159      5.621     -3.597      0.003     -32.197      -8.235
# ==============================================================================
# Omnibus:                       12.269   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               10.069
# Skew:                           1.307   Prob(JB):                      0.00651
# Kurtosis:                       5.568   Cond. No.                         3.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
tukey_oneway = pairwise_tukeyhsd(endog = _data["diff_max"], groups = _data["n_blend"])

# Display the results
tukey_oneway.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Runtime and surrogate fraction
#
# We look again at surrogate fraciton taking into account blending (i.e. we only count a step as "using the surrogate" if the blending was fully to the surrogate).

# %% [markdown]
# First we look at naively saying we used the surrogate:

# %%
frac_surrogate = []
for _hash, g  in data.groupby('hash'): 
    frac = g['used_surrogate'].mean()
    frac_surrogate.append((_hash, frac))
    
frac_surrogate = pd.DataFrame.from_records(frac_surrogate, columns=['hash', 'frac_surrogate'])

# %%
params = pd.merge(params, frac_surrogate, on='hash')

# %%
g = sns.catplot(x='n_blending_steps',
                hue='n_blending_steps',
            col='min_target_frac', 
            row='target_error',
            y='frac_surrogate',
            data=params,
            sharey=False,
            sharex=False)
plt.show()

# %% [markdown]
# Then we look at the full surrogate (and also save the runtime):

# %%
data['full_surrogate'] = data['proxima_blending_step'] == data['n_blending_steps']

# %%
data = data.reset_index()

# %%
data.loc[data['n_blending_steps'] == 0, 'full_surrogate'] = data[data['n_blending_steps'] == 0]['used_surrogate']

# %%
data.loc[data['min_target_frac'] == 1, 'full_surrogate'] = False

# %%
stuff = []
for _hash, g  in data.groupby('hash'): 
    frac = g['full_surrogate'].mean()
    n_target_by_timestep = g['target_invocations'].max() / g['timestep'].max()
    runtime = g['step_time'].sum()
    stuff.append((_hash, frac, n_target_by_timestep, runtime))
stuff = pd.DataFrame.from_records(stuff, columns=['hash', 'full_surrogate', 'n_target_by_timestep', 'runtime'])

# %%
params = pd.merge(params, stuff, on='hash')

# %%
g = sns.catplot(x='n_blending_steps',
                hue='n_blending_steps',
            col='min_target_frac', 
            row='target_error',
            y='full_surrogate',
            data=params,
            sharey=False,
            sharex=False)
plt.show()

# %%
g = sns.catplot(x='n_blending_steps',
                hue='temperature',
            col='min_target_frac', 
            row='target_error',
            y='runtime',
            kind='strip',
            data=params,
            sharey=False,
            sharex=False)
plt.show()

# %% [markdown]
# ### Zooming in on the runtime
# Looking at the same conditions as before that is target_error = 0.9 and target_frac = 0.1

# %%
_params = params.query('(target_error == 0.9 and min_target_frac == 0.1 and n_blending_steps <= 10) or min_target_frac == 1')

# %%
meth = []
for i, row in _params.iterrows():
    if row['min_target_frac'] == 1:
        meth.append('DFT (reference)')
    elif row['n_blending_steps'] == 0: 
        meth.append('Proxima')
    else: 
        meth.append('Proxima + blend')
_params['Method'] = pd.Categorical(meth, categories=['Proxima', 'Proxima + blend', 'DFT (reference)'])
# Out:
# /tmp/ipykernel_640377/3773392606.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _params['Method'] = pd.Categorical(meth, categories=['Proxima', 'Proxima + blend', 'DFT (reference)'])

# %%
_params['Method']
# Out:
# 2             Proxima
# 3             Proxima
# 4     DFT (reference)
# 10    DFT (reference)
# 12            Proxima
# 14    DFT (reference)
# 15            Proxima
# 18    DFT (reference)
# 20            Proxima
# 21    DFT (reference)
# 34    DFT (reference)
# 35            Proxima
# 43    Proxima + blend
# 44    Proxima + blend
# 46    Proxima + blend
# 57    Proxima + blend
# 64    Proxima + blend
# 77    Proxima + blend
# Name: Method, dtype: category
# Categories (3, object): ['Proxima', 'Proxima + blend', 'DFT (reference)']

# %%
_params.loc[:, 'n_blend'] = pd.Categorical(_params['n_blending_steps'].astype('str'))
_params.loc[:, 'n_blend'] = _params['n_blend'].cat.add_categories(['DFT (reference)'])
_params.loc[_params['min_target_frac'] == 1, 'n_blend'] = 'DFT (reference)'
# Out:
# /tmp/ipykernel_640377/4172146100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _params.loc[:, 'n_blend'] = pd.Categorical(_params['n_blending_steps'].astype('str'))
# /tmp/ipykernel_640377/4172146100.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0', '0', '0', '0', '0', ..., '10', '10', '10', '10', '10']
# Length: 18
# Categories (3, object): ['0', '10', 'DFT (reference)']' has dtype incompatible with category, please explicitly cast to a compatible dtype first.
#   _params.loc[:, 'n_blend'] = _params['n_blend'].cat.add_categories(['DFT (reference)'])

# %%
_params['runtime_h'] = _params['runtime'] / (60*60)
# Out:
# /tmp/ipykernel_640377/3242320047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _params['runtime_h'] = _params['runtime'] / (60*60)

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.boxplot(y='runtime_h', 
            x='n_blend', 
            hue='Method', 
            data=_params, ax=ax)
plt.ylabel('Runtime (h)')
plt.savefig('speedup.png', 
            dpi=500,
            bbox_inches='tight')
plt.show()
